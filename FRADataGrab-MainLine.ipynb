# %%
print ("Get FRA Main Lines for Kansas")
import urllib.request 
from arcpy import JSONToFeatures_conversion, Append_management, GetCount_management, Delete_management, Exists, env
env.overwriteOutput = 1
print ("get first thousand records")
MMFeatureClass = r"C:\gisdata\Roads\RailLRS1.gdb\FRAMainLine"

if Exists(MMFeatureClass):
    try:
        Delete_management(MMFeatureClass)
    except:
        print("could not be deleted")
else:
    print("no feature class exists so it will be created")
    
urlGetStartedFirstGrand = r"https://fragis.fra.dot.gov/fragis/rest/services/RailMainLine/MapServer/0/query?where=+ObjectID+%3C%3D1000&text=&objectIds=&time=&geometry=&geometryType=esriGeometryPoint&inSR=&spatialRel=esriSpatialRelIntersects&relationParam=&outFields=*&returnGeometry=true&returnTrueCurves=false&maxAllowableOffset=&geometryPrecision=&outSR=&returnIdsOnly=false&returnCountOnly=false&orderByFields=&groupByFieldsForStatistics=&outStatistics=&returnZ=false&returnM=false&gdbVersion=&returnDistinctValues=false&resultOffset=&resultRecordCount=&queryByDistance=&returnExtentsOnly=false&datumTransformation=&parameterValues=&rangeValues=&f=pjson"
urllib.request.urlretrieve(urlGetStartedFirstGrand, r"C:\gisdata\Railroads\FRAMainLine.json")
JSONToFeatures_conversion(r"C:\gisdata\Railroads\FRAMainLine.json", MMFeatureClass)

QueryReturnLimit=1000 
QueryReturn = QueryReturnLimit
count=0
featureCount = int(GetCount_management(MMFeatureClass)[0])
print ("initial feature count ="+str(featureCount))
while featureCount < 72569:
    print ("iteration count is "+str(count))
    
    print ("adding records "+str(QueryReturn)+" through "+str(QueryReturn+999))
    #urlLimited=r"https://fragis.fra.dot.gov/fragis/rest/services/Mileposts/MapServer/0/query?where=STFIPS+%3D+%2720%27+AND+ObjectID+>%3C"+str(QueryReturn)+"AND+OBJECTID+<%3D"+str(QueryReturn+999)+"&text=&objectIds=&time=&geometry=&geometryType=esriGeometryPoint&inSR=&spatialRel=esriSpatialRelIntersects&relationParam=&outFields=*&returnGeometry=true&returnTrueCurves=false&maxAllowableOffset=&geometryPrecision=&outSR=&returnIdsOnly=false&returnCountOnly=false&orderByFields=&groupByFieldsForStatistics=&outStatistics=&returnZ=true&returnM=true&gdbVersion=&returnDistinctValues=false&resultOffset=&resultRecordCount=&queryByDistance=&returnExtentsOnly=false&datumTransformation=&parameterValues=&rangeValues=&f=pjson"
    urlLimited=r"https://fragis.fra.dot.gov/fragis/rest/services/RailMainLine/MapServer/0/query?where=+ObjectID+%3E"+str(QueryReturn)+"+AND++ObjectID+%3C%3D"+str(QueryReturn+1000)+"&text=&objectIds=&time=&geometry=&geometryType=esriGeometryPoint&inSR=&spatialRel=esriSpatialRelIntersects&relationParam=&outFields=*&returnGeometry=true&returnTrueCurves=false&maxAllowableOffset=&geometryPrecision=&outSR=&returnIdsOnly=false&returnCountOnly=false&orderByFields=&groupByFieldsForStatistics=&outStatistics=&returnZ=false&returnM=false&gdbVersion=&returnDistinctValues=false&resultOffset=&resultRecordCount=&queryByDistance=&returnExtentsOnly=false&datumTransformation=&parameterValues=&rangeValues=&f=pjson"
    jsonfile = r"C:\gisdata\Railroads\FRAMainLine"+str(count)+".json"
    featureClassToAppend = MMFeatureClass+str(count)
    urllib.request.urlretrieve(urlLimited, jsonfile)
    JSONToFeatures_conversion(jsonfile, featureClassToAppend)
    Append_management(featureClassToAppend, MMFeatureClass, "TEST", None, None)
    Delete_management(featureClassToAppend)
    QueryReturn = QueryReturn+QueryReturnLimit
    count = count + 1
    featureCount = int(GetCount_management(MMFeatureClass)[0])
    print("Feature Count is "+str(featureCount))
#Sourcecount = 136656 mile markers
#250054 crossings
#TargetCount = GetCount_Management("MMFeatureClass")
# Out:
# Get FRA Crossings for Kansas
# get first thousand records
# no feature class exists so it will be created
# initial feature count =726
# iteration count is 0
# adding records 1000 through 1999
# Feature Count is 1340
# iteration count is 1
# adding records 2000 through 2999
# Feature Count is 2147
# iteration count is 2
# adding records 3000 through 3999
# Feature Count is 2638
# iteration count is 3
# adding records 4000 through 4999
# Feature Count is 3015
# iteration count is 4
# adding records 5000 through 5999
# Feature Count is 3445
# iteration count is 5
# adding records 6000 through 6999
# Feature Count is 3823
# iteration count is 6
# adding records 7000 through 7999
# Feature Count is 4214
# iteration count is 7
# adding records 8000 through 8999
# Feature Count is 4569
# iteration count is 8
# adding records 9000 through 9999
# Feature Count is 4971
# iteration count is 9
# adding records 10000 through 10999
# Feature Count is 5366
# iteration count is 10
# adding records 11000 through 11999
# Feature Count is 5796
# iteration count is 11
# adding records 12000 through 12999
# Feature Count is 6152
# iteration count is 12
# adding records 13000 through 13999
# Feature Count is 6501
# iteration count is 13
# adding records 14000 through 14999
# Feature Count is 6842
# iteration count is 14
# adding records 15000 through 15999
# Feature Count is 7212
# iteration count is 15
# adding records 16000 through 16999
# Feature Count is 7541
# iteration count is 16
# adding records 17000 through 17999
# Feature Count is 7871
# iteration count is 17
# adding records 18000 through 18999
# Feature Count is 8271
# iteration count is 18
# adding records 19000 through 19999
# Feature Count is 8678
# iteration count is 19
# adding records 20000 through 20999
# Feature Count is 9021
# iteration count is 20
# adding records 21000 through 21999
# Feature Count is 9508
# iteration count is 21
# adding records 22000 through 22999
# Feature Count is 9924
# iteration count is 22
# adding records 23000 through 23999
# Feature Count is 10329
# iteration count is 23
# adding records 24000 through 24999
# Feature Count is 10781
# iteration count is 24
# adding records 25000 through 25999
# Feature Count is 11109
# iteration count is 25
# adding records 26000 through 26999
# Feature Count is 11426
# iteration count is 26
# adding records 27000 through 27999
# Feature Count is 11754
# iteration count is 27
# adding records 28000 through 28999
# Feature Count is 12140
# iteration count is 28
# adding records 29000 through 29999
# Feature Count is 12469
# iteration count is 29
# adding records 30000 through 30999
# Feature Count is 12754
# iteration count is 30
# adding records 31000 through 31999
# Feature Count is 13104
# iteration count is 31
# adding records 32000 through 32999
# Feature Count is 13525
# iteration count is 32
# adding records 33000 through 33999
# Feature Count is 13893
# iteration count is 33
# adding records 34000 through 34999
# Feature Count is 14283
# iteration count is 34
# adding records 35000 through 35999
# Feature Count is 14648
# iteration count is 35
# adding records 36000 through 36999
# Feature Count is 15062
# iteration count is 36
# adding records 37000 through 37999
# Feature Count is 15446
# iteration count is 37
# adding records 38000 through 38999
# Feature Count is 15817
# iteration count is 38
# adding records 39000 through 39999
# Feature Count is 16189
# iteration count is 39
# adding records 40000 through 40999
# Feature Count is 16606
# iteration count is 40
# adding records 41000 through 41999
# Feature Count is 17059
# iteration count is 41
# adding records 42000 through 42999
# Feature Count is 17457
# iteration count is 42
# adding records 43000 through 43999
# Feature Count is 17805
# iteration count is 43
# adding records 44000 through 44999
# Feature Count is 18104
# iteration count is 44
# adding records 45000 through 45999
# Feature Count is 18485
# iteration count is 45
# adding records 46000 through 46999
# Feature Count is 18894
# iteration count is 46
# adding records 47000 through 47999
# Feature Count is 19253
# iteration count is 47
# adding records 48000 through 48999
# Feature Count is 19528
# iteration count is 48
# adding records 49000 through 49999
# Feature Count is 19912
# iteration count is 49
# adding records 50000 through 50999
# Feature Count is 20292
# iteration count is 50
# adding records 51000 through 51999
# Feature Count is 20599
# iteration count is 51
# adding records 52000 through 52999
# Feature Count is 20955
# iteration count is 52
# adding records 53000 through 53999
# Feature Count is 21349
# iteration count is 53
# adding records 54000 through 54999
# Feature Count is 21744
# iteration count is 54
# adding records 55000 through 55999
# Feature Count is 22180
# iteration count is 55
# adding records 56000 through 56999
# Feature Count is 22611
# iteration count is 56
# adding records 57000 through 57999
# Feature Count is 22966
# iteration count is 57
# adding records 58000 through 58999
# Feature Count is 23308
# iteration count is 58
# adding records 59000 through 59999
# Feature Count is 23738
# iteration count is 59
# adding records 60000 through 60999
# Feature Count is 24104
# iteration count is 60
# adding records 61000 through 61999
# Feature Count is 24434
# iteration count is 61
# adding records 62000 through 62999
# Feature Count is 24860
# iteration count is 62
# adding records 63000 through 63999
# Feature Count is 25202
# iteration count is 63
# adding records 64000 through 64999
# Feature Count is 25591
# iteration count is 64
# adding records 65000 through 65999
# Feature Count is 26022
# iteration count is 65
# adding records 66000 through 66999
# Feature Count is 26438
# iteration count is 66
# adding records 67000 through 67999
# Feature Count is 26899
# iteration count is 67
# adding records 68000 through 68999
# Feature Count is 27297
# iteration count is 68
# adding records 69000 through 69999
# Feature Count is 27718
# iteration count is 69
# adding records 70000 through 70999
# Feature Count is 28153
# iteration count is 70
# adding records 71000 through 71999
# Feature Count is 28500
# iteration count is 71
# adding records 72000 through 72999
# Feature Count is 28833
# iteration count is 72
# adding records 73000 through 73999
# Feature Count is 29117
# iteration count is 73
# adding records 74000 through 74999
# Feature Count is 29570
# iteration count is 74
# adding records 75000 through 75999
# Feature Count is 29939
# iteration count is 75
# adding records 76000 through 76999
# Feature Count is 30331
# iteration count is 76
# adding records 77000 through 77999
# Feature Count is 30678
# iteration count is 77
# adding records 78000 through 78999
# Feature Count is 31106
# iteration count is 78
# adding records 79000 through 79999
# Feature Count is 31472
# iteration count is 79
# adding records 80000 through 80999
# Feature Count is 31872
# iteration count is 80
# adding records 81000 through 81999
# Feature Count is 32228
# iteration count is 81
# adding records 82000 through 82999
# Feature Count is 32630
# iteration count is 82
# adding records 83000 through 83999
# Feature Count is 33078
# iteration count is 83
# adding records 84000 through 84999
# Feature Count is 33484
# iteration count is 84
# adding records 85000 through 85999
# Feature Count is 33936
# iteration count is 85
# adding records 86000 through 86999
# Feature Count is 34360
# iteration count is 86
# adding records 87000 through 87999
# Feature Count is 34762
# iteration count is 87
# adding records 88000 through 88999
# Feature Count is 35053
# iteration count is 88
# adding records 89000 through 89999
# Feature Count is 35416
# iteration count is 89
# adding records 90000 through 90999
# Feature Count is 35806
# iteration count is 90
# adding records 91000 through 91999
# Feature Count is 36138
# iteration count is 91
# adding records 92000 through 92999
# Feature Count is 36454
# iteration count is 92
# adding records 93000 through 93999
# Feature Count is 36859
# iteration count is 93
# adding records 94000 through 94999
# Feature Count is 37286
# iteration count is 94
# adding records 95000 through 95999
# Feature Count is 37651
# iteration count is 95
# adding records 96000 through 96999
# Feature Count is 37978
# iteration count is 96
# adding records 97000 through 97999
# Feature Count is 38345
# iteration count is 97
# adding records 98000 through 98999
# Feature Count is 38710
# iteration count is 98
# adding records 99000 through 99999
# Feature Count is 39090
# iteration count is 99
# adding records 100000 through 100999
# Feature Count is 39479
# iteration count is 100
# adding records 101000 through 101999
# Feature Count is 39852
# iteration count is 101
# adding records 102000 through 102999
# Feature Count is 40252
# iteration count is 102
# adding records 103000 through 103999
# Feature Count is 40674
# iteration count is 103
# adding records 104000 through 104999
# Feature Count is 41056
# iteration count is 104
# adding records 105000 through 105999
# Feature Count is 41427
# iteration count is 105
# adding records 106000 through 106999
# Feature Count is 41776
# iteration count is 106
# adding records 107000 through 107999
# Feature Count is 42158
# iteration count is 107
# adding records 108000 through 108999
# Feature Count is 42533
# iteration count is 108
# adding records 109000 through 109999
# Feature Count is 42887
# iteration count is 109
# adding records 110000 through 110999
# Feature Count is 43327
# iteration count is 110
# adding records 111000 through 111999
# Feature Count is 43685
# iteration count is 111
# adding records 112000 through 112999
# Feature Count is 44032
# iteration count is 112
# adding records 113000 through 113999
# Feature Count is 44478
# iteration count is 113
# adding records 114000 through 114999
# Feature Count is 44872
# iteration count is 114
# adding records 115000 through 115999
# Feature Count is 45224
# iteration count is 115
# adding records 116000 through 116999
# Feature Count is 45603
# iteration count is 116
# adding records 117000 through 117999
# Feature Count is 45991
# iteration count is 117
# adding records 118000 through 118999
# Feature Count is 46366
# iteration count is 118
# adding records 119000 through 119999
# Feature Count is 46737
# iteration count is 119
# adding records 120000 through 120999
# Feature Count is 47126
# iteration count is 120
# adding records 121000 through 121999
# Feature Count is 47547
# iteration count is 121
# adding records 122000 through 122999
# Feature Count is 47921
# iteration count is 122
# adding records 123000 through 123999
# Feature Count is 48253
# iteration count is 123
# adding records 124000 through 124999
# Feature Count is 48490
# iteration count is 124
# adding records 125000 through 125999
# Feature Count is 48880
# iteration count is 125
# adding records 126000 through 126999
# Feature Count is 49189
# iteration count is 126
# adding records 127000 through 127999
# Feature Count is 49556
# iteration count is 127
# adding records 128000 through 128999
# Feature Count is 49981
# iteration count is 128
# adding records 129000 through 129999
# Feature Count is 50393
# iteration count is 129
# adding records 130000 through 130999
# Feature Count is 50790
# iteration count is 130
# adding records 131000 through 131999
# Feature Count is 51232
# iteration count is 131
# adding records 132000 through 132999
# Feature Count is 51559
# iteration count is 132
# adding records 133000 through 133999
# Feature Count is 51868
# iteration count is 133
# adding records 134000 through 134999
# Feature Count is 52216
# iteration count is 134
# adding records 135000 through 135999
# Feature Count is 52603
# iteration count is 135
# adding records 136000 through 136999
# Feature Count is 53033
# iteration count is 136
# adding records 137000 through 137999
# Feature Count is 53354
# iteration count is 137
# adding records 138000 through 138999
# Feature Count is 53753
# iteration count is 138
# adding records 139000 through 139999
# Feature Count is 54064
# iteration count is 139
# adding records 140000 through 140999
# Feature Count is 54442
# iteration count is 140
# adding records 141000 through 141999
# Feature Count is 54790
# iteration count is 141
# adding records 142000 through 142999
# Feature Count is 55136
# iteration count is 142
# adding records 143000 through 143999
# Feature Count is 55512
# iteration count is 143
# adding records 144000 through 144999
# Feature Count is 55843
# iteration count is 144
# adding records 145000 through 145999
# Feature Count is 56124
# iteration count is 145
# adding records 146000 through 146999
# Feature Count is 56516
# iteration count is 146
# adding records 147000 through 147999
# Feature Count is 57000
# iteration count is 147
# adding records 148000 through 148999
# Feature Count is 57330
# iteration count is 148
# adding records 149000 through 149999
# Feature Count is 57673
# iteration count is 149
# adding records 150000 through 150999
# Feature Count is 58053
# iteration count is 150
# adding records 151000 through 151999
# Feature Count is 58474
# iteration count is 151
# adding records 152000 through 152999
# Feature Count is 58875
# iteration count is 152
# adding records 153000 through 153999
# Feature Count is 59202
# iteration count is 153
# adding records 154000 through 154999
# Feature Count is 59472
# iteration count is 154
# adding records 155000 through 155999
# Feature Count is 59714
# iteration count is 155
# adding records 156000 through 156999
# Feature Count is 59926
# iteration count is 156
# adding records 157000 through 157999
# Feature Count is 60135
# iteration count is 157
# adding records 158000 through 158999
# Feature Count is 60319
# iteration count is 158
# adding records 159000 through 159999
# Feature Count is 60530
# iteration count is 159
# adding records 160000 through 160999
# Feature Count is 60752
# iteration count is 160
# adding records 161000 through 161999
# Feature Count is 61046
# iteration count is 161
# adding records 162000 through 162999
# Feature Count is 61354
# iteration count is 162
# adding records 163000 through 163999
# Feature Count is 61999
# iteration count is 163
# adding records 164000 through 164999
# Feature Count is 62626
# iteration count is 164
# adding records 165000 through 165999
# Feature Count is 62966
# iteration count is 165
# adding records 166000 through 166999
# Feature Count is 63537
# iteration count is 166
# adding records 167000 through 167999
# Feature Count is 64532
# iteration count is 167
# adding records 168000 through 168999
# Feature Count is 65524
# iteration count is 168
# adding records 169000 through 169999
# Feature Count is 66509
# iteration count is 169
# adding records 170000 through 170999
# Feature Count is 67495
# iteration count is 170
# adding records 171000 through 171999
# Feature Count is 68469
# iteration count is 171
# adding records 172000 through 172999
# Feature Count is 69456
# iteration count is 172
# adding records 173000 through 173999
# Feature Count is 70448
# iteration count is 173
# adding records 174000 through 174999
# Feature Count is 71444
# iteration count is 174
# adding records 175000 through 175999
# Feature Count is 72412
# iteration count is 175
# adding records 176000 through 176999
# Feature Count is 72569
